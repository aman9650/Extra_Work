# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
df=pd.read_csv("COVID clinical trials.csv")
df.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# ...

# %%
df.shape
# Out:
# (5783, 27)

# %%
df.isnull().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    3303
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               886
# Outcome Measures             35
# Sponsor/Collaborators         0
# Gender                       10
# Age                           0
# Phases                     2461
# Enrollment                   34
# Funded Bys                    0
# Study Type                    0
# Study Designs                35
# Other IDs                     1
# Start Date                   34
# Primary Completion Date      36
# Completion Date              36
# First Posted                  0
# Results First Posted       5747
# Last Update Posted            0
# Locations                   585
# Study Documents            5601
# URL                           0
# dtype: int64

# %%
percent_null_value=df.isna().mean().round(4) * 100
percent_null_value
# Out:
# Rank                        0.00
# NCT Number                  0.00
# Title                       0.00
# Acronym                    57.12
# Status                      0.00
# Study Results               0.00
# Conditions                  0.00
# Interventions              15.32
# Outcome Measures            0.61
# Sponsor/Collaborators       0.00
# Gender                      0.17
# Age                         0.00
# Phases                     42.56
# Enrollment                  0.59
# Funded Bys                  0.00
# Study Type                  0.00
# Study Designs               0.61
# Other IDs                   0.02
# Start Date                  0.59
# Primary Completion Date     0.62
# Completion Date             0.62
# First Posted                0.00
# Results First Posted       99.38
# Last Update Posted          0.00
# Locations                  10.12
# Study Documents            96.85
# URL                         0.00
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5783 entries, 0 to 5782
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     5783 non-null   int64
#  1   NCT Number               5783 non-null   object
#  2   Title                    5783 non-null   object
#  3   Acronym                  2480 non-null   object
#  4   Status                   5783 non-null   object
#  5   Study Results            5783 non-null   object
#  6   Conditions               5783 non-null   object
#  7   Interventions            4897 non-null   object
#  8   Outcome Measures         5748 non-null   object
#  9   Sponsor/Collaborators    5783 non-null   object
#  10  Gender                   5773 non-null   object
#  11  Age                      5783 non-null   object
#  12  Phases                   3322 non-null   object
#  13  Enrollment               5749 non-null   float64
# ...

# %%
df["Results First Posted"].value_counts().sum()
# Out:
# 36

# %%
df["Study Documents"].value_counts().sum()
# Out:
# 182

# %%
del df["Study Documents"]
del df["Results First Posted"]

# %%
df.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'NCT Number', 'Title', 'Acronym', 'Status', 'Study Results',
#        'Conditions', 'Interventions', 'Outcome Measures',
#        'Sponsor/Collaborators', 'Gender', 'Age', 'Phases', 'Enrollment',
#        'Funded Bys', 'Study Type', 'Study Designs', 'Other IDs', 'Start Date',
#        'Primary Completion Date', 'Completion Date', 'First Posted',
#        'Last Update Posted', 'Locations', 'URL'],
#       dtype='object')

# %%
df.dropna(subset=['Outcome Measures','Enrollment','Study Designs','Other IDs','Start Date','Primary Completion Date','Completion Date','Locations'], inplace=True)

# %%
df.shape
# Out:
# (5174, 25)

# %%
# handling "gender"
df['Gender'] = df['Gender'].fillna("All")
df['Gender'].value_counts()
# Out:
# All       4982
# Female     150
# Male        42
# Name: Gender, dtype: int64

# %%
df.isnull().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    2893
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               806
# Outcome Measures              0
# Sponsor/Collaborators         0
# Gender                        0
# Age                           0
# Phases                     2205
# Enrollment                    0
# Funded Bys                    0
# Study Type                    0
# Study Designs                 0
# Other IDs                     0
# Start Date                    0
# Primary Completion Date       0
# Completion Date               0
# First Posted                  0
# Last Update Posted            0
# Locations                     0
# URL                           0
# dtype: int64

# %%
# Handling Acronym
df.Acronym.value_counts()
# Out:
# COVID-19          45
# RECOVER            5
# Covid-19           5
# SCOPE              5
# PROTECT            5
# CORONA             5
# COVID              4
# HOPE               4
# Favipiravir        3
# SALICOV            3
# PREVENT            3
# COPE               3
# COVER              3
# ASPIRE             2
# ACTION             2
# INSPIRE            2
# PEACE              2
# ACCESS             2
# RCT                2
# ENDOCOVID          2
# CP-COVID-19        2
# MilkCorona         2
# Ta1                2
# PROVID-19          2
# PiCCOVID           2
# IMPACT             2
# IPCO               2
# PHYSIO-COVID       2
# COVID-EP           2
# Isotretinoin       2
# COPPS              2
# HNS-COVID-PK       2
# CONCOR-1           2
# IMMUNO-COVID       2
# ImmunoCOVID        2
# STORM              2
# COLHEART-19        2
# PsyCOVID           2
# START              2
# STAMP              2
# COMPASS            2
# RECOVERY           2
# COVA               2
# ...

# %%
# to fill null values or acronym we can directly fill covid -19 as all are variants of it

# %%
df['Acronym'] = df['Acronym'].fillna("COVID-19")

# %%
df.Acronym.value_counts()
# Out:
# COVID-19          2938
# RECOVER              5
# Covid-19             5
# SCOPE                5
# PROTECT              5
# CORONA               5
# COVID                4
# HOPE                 4
# Favipiravir          3
# SALICOV              3
# PREVENT              3
# COPE                 3
# COVER                3
# ASPIRE               2
# ACTION               2
# INSPIRE              2
# PEACE                2
# ACCESS               2
# RCT                  2
# ENDOCOVID            2
# CP-COVID-19          2
# MilkCorona           2
# Ta1                  2
# PROVID-19            2
# PiCCOVID             2
# IMPACT               2
# IPCO                 2
# PHYSIO-COVID         2
# COVID-EP             2
# Isotretinoin         2
# COPPS                2
# HNS-COVID-PK         2
# CONCOR-1             2
# IMMUNO-COVID         2
# ImmunoCOVID          2
# STORM                2
# COLHEART-19          2
# PsyCOVID             2
# START                2
# STAMP                2
# ...

# %%
df.isnull().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                       0
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               806
# Outcome Measures              0
# Sponsor/Collaborators         0
# Gender                        0
# Age                           0
# Phases                     2205
# Enrollment                    0
# Funded Bys                    0
# Study Type                    0
# Study Designs                 0
# Other IDs                     0
# Start Date                    0
# Primary Completion Date       0
# Completion Date               0
# First Posted                  0
# Last Update Posted            0
# Locations                     0
# URL                           0
# dtype: int64

# %%
# use kaggle for refernece (imp)

# %%
df.Interventions=df.Interventions.fillna("No intervention")

# %%
df.Phases=df.Phases.fillna("Not Applicable")

# %%
df.isnull().sum()
# Out:
# Rank                       0
# NCT Number                 0
# Title                      0
# Acronym                    0
# Status                     0
# Study Results              0
# Conditions                 0
# Interventions              0
# Outcome Measures           0
# Sponsor/Collaborators      0
# Gender                     0
# Age                        0
# Phases                     0
# Enrollment                 0
# Funded Bys                 0
# Study Type                 0
# Study Designs              0
# Other IDs                  0
# Start Date                 0
# Primary Completion Date    0
# Completion Date            0
# First Posted               0
# Last Update Posted         0
# Locations                  0
# URL                        0
# dtype: int64

# %%
## NULL Values is cleaned

# %%
df.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# ...

# %%
ax=plt.figure(figsize=[9,9])

df.Status.value_counts().plot.pie(autopct = "%.2f%%", shadow=True)
# Out:
# <AxesSubplot:ylabel='Status'>

# %%
df['Study Results'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.Status.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.Gender.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.Phases.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
ax=plt.figure(figsize=[5,9])

df['Study Type'].value_counts().plot.pie(autopct = "%.2f%%", shadow=True)
# Out:
# <AxesSubplot:ylabel='Study Type'>

# %%
df['Funded Bys'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# ...

# %%
ax=plt.figure(figsize=[18,6])
df.Enrollment.value_counts().plot.hist(color="orange")
plt.title("Distribution of Enrollment Fee")
plt.show()

# %%
df.to_csv('cleaned.csv')

# %%
sns.pairplot(df)

# %%
sns.headtmap(data.corr)
